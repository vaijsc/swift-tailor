# %%
import h5py

file_path = '/home/phphuc/Desktop/GarmentRecon/omages/datasets/ABO/omages/df_p64_m02_res64.h5'
with h5py.File(file_path, 'r') as h5_file:
    # List all groups
    print("Keys: %s" % h5_file.keys())
    # Get the data
    data = h5_file['omage'][:]
# Out:
# Keys: <KeysViewHDF5 ['omage']>

# %%
import numpy as np

np.save('test.npy', data[0])

# %%
import matplotlib.pyplot as plt

obj_id = 421
fig, axes = plt.subplots(3, 4, figsize=(15, 10))
for i in range(12):
    axid = i // 4
    axes[axid, i % 4].imshow(data[obj_id][:,:,i])
    axes[axid, i % 4].axis('off')
    
plt.tight_layout()
plt.show()

# %%
plt.imshow(data[421][...,0:3] / 65535)

# %%
# !p

# %%
from lightning.pytorch import Trainer

# %%
data[obj_id][:,:,11].max()
# Out:
# 30981

# %%
data.shape
# Out:
# (7953, 64, 64, 12)
